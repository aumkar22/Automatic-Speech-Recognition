# %%
import os
import numpy as np
import keras
import math
import itertools
import pandas as pd
import matplotlib.pyplot as plt
from kapre.utils import Normalization2D
#from kapre.time_frequency import Melspectrogram
#from kapre.augmentation import AdditiveNoise
from keras.models import Sequential
from keras.layers import *
from keras import backend as k
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from keras.preprocessing import sequence
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import MinMaxScaler

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
train_feat = np.load('train_feat.npy')
val_feat = np.load('val_feat.npy')
test_feat = np.load('test_feat.npy')

'''train_feat = np.load('asr_train.npy')
val_feat = np.load('asr_val.npy')
test_feat = np.load('asr_test.npy')'''

ytrain = np.load('ytrain.npy')
yval = np.load('yval.npy')
ytest = np.load('ytest.npy')

# %%
train_feat.shape
# Out:
# (84843, 98, 40)

# %%
test_feat.shape
# Out:
# (11005, 98, 40)

# %%
ytest.shape
# Out:
# (11005, 35)

# %%
inputLength = 16000
samplingrate = 16000
features_dim = 98
wide = 40
N1 = 64
N2 = 1
Nfc1 = 120
Nfc2 = 60
L1 = 14
L2 = 14
out_dim = 35
BATCH_SIZE = 128

# %%
x_train = sequence.pad_sequences(train_feat, maxlen = inputLength)

# %%
x_train.shape

# %%
x_val = sequence.pad_sequences(val_feat, maxlen = inputLength)

# %%
x_val.shape

# %%
x_test = sequence.pad_sequences(test_feat, maxlen = inputLength)

# %%
x_test.shape

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
xtrain = scaler.fit_transform(x_train)
xval = scaler.fit_transform(x_val)
xtest = scaler.fit_transform(x_test)

# %%
model = Sequential()

model.add(Normalization2D(int_axis = 1, input_shape=(features_dim, wide, 1)))

model.add(Permute((2, 1, 3)))

model.add(Conv2D(N1, kernel_size = (1, 4), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))
    
model.add(Conv2D(N2, kernel_size = (1, 4), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))

model.add(Flatten())

model.add(Dense(Nfc1, activation = 'relu'))

model.add(Dropout(0.5))

model.add(Dense(out_dim, activation = 'softmax'))

adam_ = optimizers.Adam(lr = 1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = adam_, metrics = ['categorical_accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization2d_1 (Normaliza (None, 98, 40, 1)         0
# _________________________________________________________________
# permute_1 (Permute)          (None, 40, 98, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 48, 64)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 48, 64)        192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 47, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 22, 1)         257
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 39, 22, 1)         3
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 38, 21, 1)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 798)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               95880
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 35)                4235
# =================================================================
# Total params: 100,887
# Trainable params: 100,757
# Non-trainable params: 130
# _________________________________________________________________

# %%
batches = int(len(train_feat)/BATCH_SIZE)

# %%
def batch_generator():
    
    while True:

        for batch in range(batches):
            
            x_ = []
            data = train_feat[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            label = ytrain[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            
            for i in data:
                x_.append(np.reshape(i, (features_dim, wide, 1)))
                 
            x = np.asarray(x_)
            yield (x, label)

# %%
x_val = []

for i in range(len(val_feat)):
    x_val.append(np.reshape(val_feat[i], (features_dim, wide, 1)))
    
valx = np.asarray(x_val)

# %%
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate

# %%
lrate = LearningRateScheduler(step_decay)

# %%
checkpointer = ModelCheckpoint(filepath='checkpoint_asr.h5', monitor='val_categorical_accuracy', save_best_only=True)

# %%
earlystopper = EarlyStopping(monitor='val_categorical_accuracy', patience=10, verbose=1)

# %%
history = model.fit_generator(batch_generator(), steps_per_epoch = batches, epochs = 500, validation_data=(valx, yval), 
                              callbacks=[checkpointer, earlystopper, lrate], shuffle = True)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 13s 20ms/step - loss: 3.1124 - categorical_accuracy: 0.1401 - val_loss: 2.4610 - val_categorical_accuracy: 0.3161
# Epoch 2/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.6360 - categorical_accuracy: 0.2496 - val_loss: 2.1654 - val_categorical_accuracy: 0.3998
# Epoch 3/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.4732 - categorical_accuracy: 0.2921 - val_loss: 2.2980 - val_categorical_accuracy: 0.4077
# Epoch 4/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.3970 - categorical_accuracy: 0.3104 - val_loss: 1.9436 - val_categorical_accuracy: 0.4580
# Epoch 5/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.3310 - categorical_accuracy: 0.3315 - val_loss: 2.0556 - val_categorical_accuracy: 0.4438
# Epoch 6/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.2886 - categorical_accuracy: 0.3417 - val_loss: 1.8893 - val_categorical_accuracy: 0.4771
# Epoch 7/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.2373 - categorical_accuracy: 0.3535 - val_loss: 1.9030 - val_categorical_accuracy: 0.4870
# Epoch 8/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.2074 - categorical_accuracy: 0.3608 - val_loss: 1.8224 - val_categorical_accuracy: 0.5019
# Epoch 9/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 2.1835 - categorical_accuracy: 0.3680 - val_loss: 1.7616 - val_categorical_accuracy: 0.5115
# Epoch 10/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.1133 - categorical_accuracy: 0.3870 - val_loss: 1.7819 - val_categorical_accuracy: 0.5294
# Epoch 11/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.1020 - categorical_accuracy: 0.3876 - val_loss: 1.7304 - val_categorical_accuracy: 0.5288
# Epoch 12/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0887 - categorical_accuracy: 0.3934 - val_loss: 1.7320 - val_categorical_accuracy: 0.5285
# Epoch 13/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0848 - categorical_accuracy: 0.3924 - val_loss: 1.7706 - val_categorical_accuracy: 0.5255
# Epoch 14/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0736 - categorical_accuracy: 0.3958 - val_loss: 1.7104 - val_categorical_accuracy: 0.5371
# Epoch 15/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0604 - categorical_accuracy: 0.3985 - val_loss: 1.7228 - val_categorical_accuracy: 0.5372
# Epoch 16/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0438 - categorical_accuracy: 0.4047 - val_loss: 1.6602 - val_categorical_accuracy: 0.5412
# Epoch 17/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0583 - categorical_accuracy: 0.4022 - val_loss: 1.7018 - val_categorical_accuracy: 0.5373
# Epoch 18/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0444 - categorical_accuracy: 0.4041 - val_loss: 1.7095 - val_categorical_accuracy: 0.5396
# Epoch 19/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 2.0248 - categorical_accuracy: 0.4092 - val_loss: 1.6541 - val_categorical_accuracy: 0.5539
# Epoch 20/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9921 - categorical_accuracy: 0.4163 - val_loss: 1.6386 - val_categorical_accuracy: 0.5533
# Epoch 21/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9857 - categorical_accuracy: 0.4186 - val_loss: 1.6298 - val_categorical_accuracy: 0.5549
# Epoch 22/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9797 - categorical_accuracy: 0.4216 - val_loss: 1.6348 - val_categorical_accuracy: 0.5560
# Epoch 23/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9734 - categorical_accuracy: 0.4223 - val_loss: 1.6114 - val_categorical_accuracy: 0.5600
# Epoch 24/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9715 - categorical_accuracy: 0.4231 - val_loss: 1.6323 - val_categorical_accuracy: 0.5566
# Epoch 25/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9702 - categorical_accuracy: 0.4252 - val_loss: 1.6357 - val_categorical_accuracy: 0.5551
# Epoch 26/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9692 - categorical_accuracy: 0.4247 - val_loss: 1.6573 - val_categorical_accuracy: 0.5484
# Epoch 27/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9642 - categorical_accuracy: 0.4258 - val_loss: 1.6424 - val_categorical_accuracy: 0.5521
# Epoch 28/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9623 - categorical_accuracy: 0.4255 - val_loss: 1.6581 - val_categorical_accuracy: 0.5534
# Epoch 29/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9602 - categorical_accuracy: 0.4254 - val_loss: 1.6233 - val_categorical_accuracy: 0.5547
# Epoch 30/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9489 - categorical_accuracy: 0.4291 - val_loss: 1.6032 - val_categorical_accuracy: 0.5597
# Epoch 31/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9432 - categorical_accuracy: 0.4321 - val_loss: 1.6091 - val_categorical_accuracy: 0.5587
# Epoch 32/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9433 - categorical_accuracy: 0.4298 - val_loss: 1.6061 - val_categorical_accuracy: 0.5581
# Epoch 33/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9396 - categorical_accuracy: 0.4310 - val_loss: 1.6064 - val_categorical_accuracy: 0.5603
# Epoch 34/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9416 - categorical_accuracy: 0.4300 - val_loss: 1.6019 - val_categorical_accuracy: 0.5588
# Epoch 35/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9379 - categorical_accuracy: 0.4323 - val_loss: 1.6036 - val_categorical_accuracy: 0.5605
# Epoch 36/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9339 - categorical_accuracy: 0.4341 - val_loss: 1.6026 - val_categorical_accuracy: 0.5616
# Epoch 37/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9371 - categorical_accuracy: 0.4303 - val_loss: 1.6012 - val_categorical_accuracy: 0.5606
# Epoch 38/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9352 - categorical_accuracy: 0.4333 - val_loss: 1.5985 - val_categorical_accuracy: 0.5608
# Epoch 39/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9296 - categorical_accuracy: 0.4341 - val_loss: 1.5983 - val_categorical_accuracy: 0.5612
# Epoch 40/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9232 - categorical_accuracy: 0.4356 - val_loss: 1.5915 - val_categorical_accuracy: 0.5626
# Epoch 41/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9256 - categorical_accuracy: 0.4355 - val_loss: 1.5935 - val_categorical_accuracy: 0.5646
# Epoch 42/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9232 - categorical_accuracy: 0.4332 - val_loss: 1.5876 - val_categorical_accuracy: 0.5645
# Epoch 43/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9295 - categorical_accuracy: 0.4357 - val_loss: 1.5909 - val_categorical_accuracy: 0.5649
# Epoch 44/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9282 - categorical_accuracy: 0.4341 - val_loss: 1.5887 - val_categorical_accuracy: 0.5655
# Epoch 45/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9292 - categorical_accuracy: 0.4355 - val_loss: 1.5933 - val_categorical_accuracy: 0.5630
# Epoch 46/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9273 - categorical_accuracy: 0.4351 - val_loss: 1.5970 - val_categorical_accuracy: 0.5627
# Epoch 47/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9301 - categorical_accuracy: 0.4333 - val_loss: 1.6018 - val_categorical_accuracy: 0.5626
# Epoch 48/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9249 - categorical_accuracy: 0.4348 - val_loss: 1.5961 - val_categorical_accuracy: 0.5626
# Epoch 49/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9320 - categorical_accuracy: 0.4335 - val_loss: 1.5921 - val_categorical_accuracy: 0.5627
# Epoch 50/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9277 - categorical_accuracy: 0.4355 - val_loss: 1.6018 - val_categorical_accuracy: 0.5626
# Epoch 51/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9285 - categorical_accuracy: 0.4327 - val_loss: 1.5977 - val_categorical_accuracy: 0.5617
# Epoch 52/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9326 - categorical_accuracy: 0.4346 - val_loss: 1.5960 - val_categorical_accuracy: 0.5607
# Epoch 53/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9227 - categorical_accuracy: 0.4362 - val_loss: 1.5941 - val_categorical_accuracy: 0.5614
# Epoch 54/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 1.9182 - categorical_accuracy: 0.4362 - val_loss: 1.5990 - val_categorical_accuracy: 0.5605
# Epoch 00054: early stopping

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
testEval = model.evaluate(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), ytest, batch_size = BATCH_SIZE)
# Out:
# 11005/11005 [==============================] - 1s 55us/step

# %%
print('Evaluation scores: \nMetrics: {} \nTest: {}'.format(model.metrics_names, testEval))
# Out:
# Evaluation scores:
# Metrics: ['loss', 'categorical_accuracy']
# Test: [1.687381970237895, 0.5345751931157128]

# %%
ROOT_DIR = os.path.normpath(os.path.join(os.path.dirname(os.path.realpath('__file__'))))
DATA_INFO = os.path.join(ROOT_DIR, 'data_asr', 'data_info')

# %%
test_files = pd.read_csv(os.path.join(DATA_INFO, 'testing_list.txt'), sep = ' ', header = None)[0].tolist()

# %%
test_lab = [os.path.dirname(i) for i in test_files]

# %%
lab = LabelEncoder()

test_encode = lab.fit_transform(test_lab)

# %%
test_encode
# Out:
# array([22, 22, 22, ..., 10, 10, 10])

# %%
y_pred = model.predict(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), verbose=1)
# Out:
# 11005/11005 [==============================] - 1s 81us/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.figure(figsize=(25,25))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.3f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), size=11,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)
    plt.savefig('cnn1_1k.png', dpi = 400)
    plt.tight_layout()

# %%
classes = ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 
          'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 
          'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree',
          'two', 'up', 'visual', 'wow', 'yes', 'zero']

# %%
np.argmax(y_pred, 1)
# Out:
# array([22, 15, 22, ..., 25, 19, 10])

# %%
cm = confusion_matrix(test_encode, np.argmax(y_pred, 1))

# %%
plot_confusion_matrix(cm, classes, normalize=True)
# Out:
# Normalized confusion matrix

# %%
print(classification_report(test_encode, np.argmax(y_pred, 1), target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#     backward       0.62      0.35      0.45       165
#          bed       0.41      0.28      0.33       207
#         bird       0.61      0.65      0.63       185
#          cat       0.48      0.41      0.44       194
#          dog       0.40      0.17      0.24       220
#         down       0.49      0.43      0.46       406
#        eight       0.58      0.65      0.61       408
#         five       0.54      0.48      0.51       445
#       follow       0.58      0.34      0.43       172
#      forward       0.53      0.21      0.30       155
#         four       0.56      0.65      0.60       400
#           go       0.40      0.42      0.41       402
#        happy       0.74      0.61      0.66       203
#        house       0.79      0.54      0.65       191
#        learn       0.41      0.19      0.26       161
#         left       0.55      0.55      0.55       412
#       marvin       0.63      0.43      0.51       195
#         nine       0.53      0.60      0.56       408
#           no       0.41      0.46      0.43       405
#          off       0.58      0.55      0.57       402
#           on       0.51      0.48      0.50       396
#          one       0.51      0.63      0.56       399
#        right       0.60      0.57      0.58       396
#        seven       0.54      0.73      0.62       406
#       sheila       0.82      0.65      0.72       212
#          six       0.55      0.72      0.63       394
#         stop       0.44      0.57      0.50       411
#        three       0.56      0.62      0.59       405
#         tree       0.77      0.28      0.42       193
#          two       0.46      0.67      0.54       424
#           up       0.29      0.41      0.34       425
#       visual       0.71      0.39      0.51       165
#          wow       0.71      0.43      0.53       206
#          yes       0.62      0.68      0.65       419
#         zero       0.64      0.65      0.65       418
#
#    micro avg       0.53      0.53      0.53     11005
#    macro avg       0.56      0.50      0.51     11005
# weighted avg       0.54      0.53      0.53     11005
