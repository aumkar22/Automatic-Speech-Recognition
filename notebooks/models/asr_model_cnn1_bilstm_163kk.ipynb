# %%
import os
import numpy as np
import keras
import math
import itertools
import pandas as pd
import matplotlib.pyplot as plt
from kapre.utils import Normalization2D
from keras.models import Sequential
from keras.layers import *
from keras import backend as k
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from keras.preprocessing import sequence
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
train_feat = np.load('train_feat.npy')
val_feat = np.load('val_feat.npy')
test_feat = np.load('test_feat.npy')

ytrain = np.load('ytrain.npy')
yval = np.load('yval.npy')
ytest = np.load('ytest.npy')

# %%
features_dim = 98
wide = 40
N1 = 128
N2 = 1
Nfc1 = 60
out_dim = 35
BATCH_SIZE = 128

# %%
model = Sequential()

model.add(Normalization2D(int_axis = 1, input_shape=(features_dim, wide, 1)))

model.add(Permute((2, 1, 3)))

model.add(Conv2D(N1, kernel_size = (1, 2), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))
    
model.add(Conv2D(N2, kernel_size = (1, 2), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))

model.add(Lambda(lambda q: K.squeeze(q, -1)))

model.add(Bidirectional(CuDNNLSTM(32, return_sequences = True)))

model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(Nfc1, activation = 'relu'))

model.add(Dropout(0.2))

model.add(Dense(out_dim, activation = 'softmax'))

adam_ = optimizers.Adam(lr = 1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = adam_, metrics = ['categorical_accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization2d_1 (Normaliza (None, 98, 40, 1)         0
# _________________________________________________________________
# permute_1 (Permute)          (None, 40, 98, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 49, 128)       384
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 49, 128)       384
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 48, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 24, 1)         257
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 39, 24, 1)         3
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 38, 23, 1)         0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 38, 23)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 38, 64)            14592
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 38, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2432)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                145980
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 35)                2135
# =================================================================
# Total params: 163,735
# Trainable params: 163,477
# Non-trainable params: 258
# _________________________________________________________________

# %%
batches = int(len(train_feat)/BATCH_SIZE)

# %%
def batch_generator():
    
    while True:

        for batch in range(batches):
            
            x_ = []
            data = train_feat[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            label = ytrain[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            
            for i in data:
                x_.append(np.reshape(i, (features_dim, wide, 1)))
                 
            x = np.asarray(x_)
            yield (x, label)

# %%
x_val = []

for i in range(len(val_feat)):
    x_val.append(np.reshape(val_feat[i], (features_dim, wide, 1)))
    
valx = np.asarray(x_val)

# %%
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate

# %%
lrate = LearningRateScheduler(step_decay)

# %%
checkpointer = ModelCheckpoint(filepath='checkpoint_asr.h5', monitor='val_categorical_accuracy', save_best_only=True)

# %%
earlystopper = EarlyStopping(monitor='val_categorical_accuracy', patience=10, verbose=1)

# %%
history = model.fit_generator(batch_generator(), steps_per_epoch = batches, epochs = 500, validation_data=(valx, yval), 
                              callbacks=[checkpointer, earlystopper, lrate], shuffle = True)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 24s 36ms/step - loss: 2.6828 - categorical_accuracy: 0.2495 - val_loss: 2.0095 - val_categorical_accuracy: 0.4326
# Epoch 2/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 2.0434 - categorical_accuracy: 0.4116 - val_loss: 1.6852 - val_categorical_accuracy: 0.5262
# Epoch 3/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 1.7625 - categorical_accuracy: 0.4860 - val_loss: 1.4405 - val_categorical_accuracy: 0.5950
# Epoch 4/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 33ms/step - loss: 1.5752 - categorical_accuracy: 0.5381 - val_loss: 1.2767 - val_categorical_accuracy: 0.6383
# Epoch 5/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 1.4544 - categorical_accuracy: 0.5715 - val_loss: 1.2041 - val_categorical_accuracy: 0.6624
# Epoch 6/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 1.3679 - categorical_accuracy: 0.5945 - val_loss: 1.1564 - val_categorical_accuracy: 0.6672
# Epoch 7/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 1.2946 - categorical_accuracy: 0.6141 - val_loss: 1.0875 - val_categorical_accuracy: 0.6854
# Epoch 8/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 34ms/step - loss: 1.2693 - categorical_accuracy: 0.6225 - val_loss: 1.0441 - val_categorical_accuracy: 0.7006
# Epoch 9/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 22s 33ms/step - loss: 1.2218 - categorical_accuracy: 0.6360 - val_loss: 1.0609 - val_categorical_accuracy: 0.6938
# Epoch 10/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 33ms/step - loss: 1.1397 - categorical_accuracy: 0.6560 - val_loss: 0.9871 - val_categorical_accuracy: 0.7151
# Epoch 11/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.1079 - categorical_accuracy: 0.6661 - val_loss: 0.9847 - val_categorical_accuracy: 0.7138
# Epoch 12/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0845 - categorical_accuracy: 0.6725 - val_loss: 0.9539 - val_categorical_accuracy: 0.7227
# Epoch 13/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0716 - categorical_accuracy: 0.6760 - val_loss: 0.9444 - val_categorical_accuracy: 0.7242
# Epoch 14/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 33ms/step - loss: 1.0535 - categorical_accuracy: 0.6827 - val_loss: 0.9348 - val_categorical_accuracy: 0.7249
# Epoch 15/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0409 - categorical_accuracy: 0.6856 - val_loss: 0.9800 - val_categorical_accuracy: 0.7155
# Epoch 16/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0365 - categorical_accuracy: 0.6874 - val_loss: 0.9332 - val_categorical_accuracy: 0.7266
# Epoch 17/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0202 - categorical_accuracy: 0.6910 - val_loss: 0.9317 - val_categorical_accuracy: 0.7285
# Epoch 18/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0092 - categorical_accuracy: 0.6930 - val_loss: 0.9200 - val_categorical_accuracy: 0.7309
# Epoch 19/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 22s 34ms/step - loss: 1.0150 - categorical_accuracy: 0.6924 - val_loss: 0.9261 - val_categorical_accuracy: 0.7286
# Epoch 20/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9852 - categorical_accuracy: 0.6999 - val_loss: 0.8983 - val_categorical_accuracy: 0.7370
# Epoch 21/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9720 - categorical_accuracy: 0.7027 - val_loss: 0.9009 - val_categorical_accuracy: 0.7363
# Epoch 22/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9709 - categorical_accuracy: 0.7055 - val_loss: 0.8990 - val_categorical_accuracy: 0.7393
# Epoch 23/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9660 - categorical_accuracy: 0.7062 - val_loss: 0.8928 - val_categorical_accuracy: 0.7376
# Epoch 24/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 23s 34ms/step - loss: 0.9627 - categorical_accuracy: 0.7061 - val_loss: 0.8915 - val_categorical_accuracy: 0.7373
# Epoch 25/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9579 - categorical_accuracy: 0.7079 - val_loss: 0.8898 - val_categorical_accuracy: 0.7409
# Epoch 26/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9486 - categorical_accuracy: 0.7111 - val_loss: 0.8912 - val_categorical_accuracy: 0.7407
# Epoch 27/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9467 - categorical_accuracy: 0.7107 - val_loss: 0.8845 - val_categorical_accuracy: 0.7407
# Epoch 28/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 33ms/step - loss: 0.9469 - categorical_accuracy: 0.7105 - val_loss: 0.8832 - val_categorical_accuracy: 0.7419
# Epoch 29/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 22s 33ms/step - loss: 0.9360 - categorical_accuracy: 0.7145 - val_loss: 0.8809 - val_categorical_accuracy: 0.7413
# Epoch 30/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9310 - categorical_accuracy: 0.7161 - val_loss: 0.8751 - val_categorical_accuracy: 0.7431
# Epoch 31/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9268 - categorical_accuracy: 0.7161 - val_loss: 0.8747 - val_categorical_accuracy: 0.7442
# Epoch 32/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 33ms/step - loss: 0.9241 - categorical_accuracy: 0.7159 - val_loss: 0.8746 - val_categorical_accuracy: 0.7432
# Epoch 33/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 33ms/step - loss: 0.9221 - categorical_accuracy: 0.7181 - val_loss: 0.8726 - val_categorical_accuracy: 0.7443
# Epoch 34/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9174 - categorical_accuracy: 0.7203 - val_loss: 0.8731 - val_categorical_accuracy: 0.7434
# Epoch 35/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9210 - categorical_accuracy: 0.7175 - val_loss: 0.8717 - val_categorical_accuracy: 0.7432
# Epoch 36/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9134 - categorical_accuracy: 0.7187 - val_loss: 0.8704 - val_categorical_accuracy: 0.7459
# Epoch 37/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9151 - categorical_accuracy: 0.7185 - val_loss: 0.8734 - val_categorical_accuracy: 0.7444
# Epoch 38/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9200 - categorical_accuracy: 0.7180 - val_loss: 0.8738 - val_categorical_accuracy: 0.7422
# Epoch 39/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9216 - categorical_accuracy: 0.7168 - val_loss: 0.8745 - val_categorical_accuracy: 0.7430
# Epoch 40/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9176 - categorical_accuracy: 0.7175 - val_loss: 0.8693 - val_categorical_accuracy: 0.7455
# Epoch 41/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9170 - categorical_accuracy: 0.7190 - val_loss: 0.8689 - val_categorical_accuracy: 0.7451
# Epoch 42/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 33ms/step - loss: 0.9119 - categorical_accuracy: 0.7208 - val_loss: 0.8730 - val_categorical_accuracy: 0.7431
# Epoch 43/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9118 - categorical_accuracy: 0.7202 - val_loss: 0.8701 - val_categorical_accuracy: 0.7437
# Epoch 44/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9114 - categorical_accuracy: 0.7201 - val_loss: 0.8689 - val_categorical_accuracy: 0.7437
# Epoch 45/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9107 - categorical_accuracy: 0.7207 - val_loss: 0.8684 - val_categorical_accuracy: 0.7446
# Epoch 46/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 22s 34ms/step - loss: 0.9061 - categorical_accuracy: 0.7209 - val_loss: 0.8674 - val_categorical_accuracy: 0.7434
# Epoch 00046: early stopping

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
testEval = model.evaluate(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), ytest, batch_size = BATCH_SIZE)
# Out:
# 11005/11005 [==============================] - 1s 92us/step

# %%
print('Evaluation scores: \nMetrics: {} \nTest: {}'.format(model.metrics_names, testEval))
# Out:
# Evaluation scores:
# Metrics: ['loss', 'categorical_accuracy']
# Test: [1.0363783510150502, 0.695411177062815]

# %%
ROOT_DIR = os.path.normpath(os.path.join(os.path.dirname(os.path.realpath('__file__'))))
DATA_INFO = os.path.join(ROOT_DIR, 'data_asr', 'data_info')

# %%
test_files = pd.read_csv(os.path.join(DATA_INFO, 'testing_list.txt'), sep = ' ', header = None)[0].tolist()

# %%
test_lab = [os.path.dirname(i) for i in test_files]

# %%
lab = LabelEncoder()

test_encode = lab.fit_transform(test_lab)

# %%
y_pred = model.predict(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), verbose=1)
# Out:
# 11005/11005 [==============================] - 2s 144us/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.figure(figsize=(25,25))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.3f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), size=11,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)
    plt.tight_layout()

# %%
classes = ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 
          'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 
          'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree',
          'two', 'up', 'visual', 'wow', 'yes', 'zero']

# %%
cm = confusion_matrix(test_encode, np.argmax(y_pred, 1))

# %%
plot_confusion_matrix(cm, classes, normalize=True)
# Out:
# Normalized confusion matrix

# %%
print(classification_report(test_encode, np.argmax(y_pred, 1), target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#     backward       0.74      0.60      0.66       165
#          bed       0.68      0.61      0.64       207
#         bird       0.70      0.76      0.73       185
#          cat       0.66      0.69      0.67       194
#          dog       0.72      0.50      0.59       220
#         down       0.64      0.60      0.62       406
#        eight       0.73      0.81      0.77       408
#         five       0.76      0.67      0.71       445
#       follow       0.60      0.54      0.57       172
#      forward       0.60      0.40      0.48       155
#         four       0.67      0.72      0.69       400
#           go       0.53      0.57      0.55       402
#        happy       0.77      0.77      0.77       203
#        house       0.80      0.80      0.80       191
#        learn       0.51      0.46      0.48       161
#         left       0.73      0.70      0.72       412
#       marvin       0.78      0.67      0.72       195
#         nine       0.66      0.75      0.70       408
#           no       0.57      0.59      0.58       405
#          off       0.74      0.70      0.72       402
#           on       0.67      0.68      0.67       396
#          one       0.70      0.76      0.73       399
#        right       0.73      0.68      0.70       396
#        seven       0.69      0.84      0.76       406
#       sheila       0.84      0.81      0.82       212
#          six       0.78      0.85      0.81       394
#         stop       0.77      0.77      0.77       411
#        three       0.69      0.69      0.69       405
#         tree       0.65      0.55      0.59       193
#          two       0.67      0.73      0.70       424
#           up       0.54      0.61      0.58       425
#       visual       0.67      0.67      0.67       165
#          wow       0.80      0.62      0.70       206
#          yes       0.78      0.80      0.79       419
#         zero       0.77      0.75      0.76       418
#
#    micro avg       0.69      0.69      0.69     11005
#    macro avg       0.70      0.68      0.68     11005
# weighted avg       0.70      0.69      0.69     11005
