# %%
import os
import numpy as np
import keras
import math
import itertools
import pandas as pd
import matplotlib.pyplot as plt
from kapre.utils import Normalization2D
from keras.models import Sequential
from keras.layers import *
from keras import backend as k
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from keras.preprocessing import sequence
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
train_feat = np.load('train_feat.npy')
val_feat = np.load('val_feat.npy')
test_feat = np.load('test_feat.npy')

ytrain = np.load('ytrain.npy')
yval = np.load('yval.npy')
ytest = np.load('ytest.npy')

# %%
features_dim = 98
wide = 40
N1 = 64
N2 = 1
Nfc1 = 120
Nfc2 = 240
out_dim = 35
BATCH_SIZE = 128

# %%
model = Sequential()

model.add(Normalization2D(int_axis = 1, input_shape=(features_dim, wide, 1)))

model.add(Permute((2, 1, 3)))

model.add(Conv2D(N1, kernel_size = (1, 4), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))
    
model.add(Conv2D(N2, kernel_size = (1, 4), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))

model.add(Flatten())

model.add(Dense(Nfc1, activation = 'relu'))

#model.add(Dropout(0.3))

model.add(Dense(Nfc2, activation = 'relu'))

#model.add(Dropout(0.3))

model.add(Dense(out_dim, activation = 'softmax'))

adam_ = optimizers.Adam(lr = 1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = adam_, metrics = ['categorical_accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization2d_1 (Normaliza (None, 98, 40, 1)         0
# _________________________________________________________________
# permute_1 (Permute)          (None, 40, 98, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 48, 64)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 48, 64)        192
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 47, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 22, 1)         257
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 39, 22, 1)         3
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 38, 21, 1)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 798)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               95880
# _________________________________________________________________
# dense_2 (Dense)              (None, 240)               29040
# _________________________________________________________________
# dense_3 (Dense)              (None, 35)                8435
# =================================================================
# Total params: 134,127
# Trainable params: 133,997
# Non-trainable params: 130
# _________________________________________________________________

# %%
batches = int(len(train_feat)/BATCH_SIZE)

# %%
def batch_generator():
    
    while True:

        for batch in range(batches):
            
            x_ = []
            data = train_feat[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            label = ytrain[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            
            for i in data:
                x_.append(np.reshape(i, (features_dim, wide, 1)))
                 
            x = np.asarray(x_)
            yield (x, label)

# %%
x_val = []

for i in range(len(val_feat)):
    x_val.append(np.reshape(val_feat[i], (features_dim, wide, 1)))
    
valx = np.asarray(x_val)

# %%
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate

# %%
lrate = LearningRateScheduler(step_decay)

# %%
checkpointer = ModelCheckpoint(filepath='checkpoint_asr.h5', monitor='val_categorical_accuracy', save_best_only=True)

# %%
earlystopper = EarlyStopping(monitor='val_categorical_accuracy', patience=10, verbose=1)

# %%
history = model.fit_generator(batch_generator(), steps_per_epoch = batches, epochs = 500, validation_data=(valx, yval), 
                              callbacks=[checkpointer, earlystopper, lrate], shuffle = True)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 13s 20ms/step - loss: 2.2140 - categorical_accuracy: 0.3733 - val_loss: 1.7257 - val_categorical_accuracy: 0.5009
# Epoch 2/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 1.5762 - categorical_accuracy: 0.5430 - val_loss: 1.5062 - val_categorical_accuracy: 0.5638
# Epoch 3/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 1.3726 - categorical_accuracy: 0.5971 - val_loss: 1.5230 - val_categorical_accuracy: 0.5726
# Epoch 4/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 1.2306 - categorical_accuracy: 0.6371 - val_loss: 1.3436 - val_categorical_accuracy: 0.6082
# Epoch 5/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 1.1415 - categorical_accuracy: 0.6612 - val_loss: 1.3144 - val_categorical_accuracy: 0.6249
# Epoch 6/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 1.0971 - categorical_accuracy: 0.6733 - val_loss: 1.4350 - val_categorical_accuracy: 0.6259
# Epoch 7/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 0.9963 - categorical_accuracy: 0.7007 - val_loss: 1.2549 - val_categorical_accuracy: 0.6419
# Epoch 8/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 0.9519 - categorical_accuracy: 0.7151 - val_loss: 1.3561 - val_categorical_accuracy: 0.6401
# Epoch 9/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 12s 18ms/step - loss: 0.9227 - categorical_accuracy: 0.7214 - val_loss: 1.4776 - val_categorical_accuracy: 0.6313
# Epoch 10/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.8143 - categorical_accuracy: 0.7528 - val_loss: 1.2900 - val_categorical_accuracy: 0.6551
# Epoch 11/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.7702 - categorical_accuracy: 0.7665 - val_loss: 1.2671 - val_categorical_accuracy: 0.6584
# Epoch 12/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.7454 - categorical_accuracy: 0.7746 - val_loss: 1.2965 - val_categorical_accuracy: 0.6556
# Epoch 13/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.7483 - categorical_accuracy: 0.7730 - val_loss: 1.2938 - val_categorical_accuracy: 0.6580
# Epoch 14/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.7054 - categorical_accuracy: 0.7876 - val_loss: 1.3040 - val_categorical_accuracy: 0.6578
# Epoch 15/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.6808 - categorical_accuracy: 0.7951 - val_loss: 1.2985 - val_categorical_accuracy: 0.6583
# Epoch 16/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.6661 - categorical_accuracy: 0.8003 - val_loss: 1.3046 - val_categorical_accuracy: 0.6587
# Epoch 17/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.6476 - categorical_accuracy: 0.8058 - val_loss: 1.2907 - val_categorical_accuracy: 0.6525
# Epoch 18/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.6336 - categorical_accuracy: 0.8102 - val_loss: 1.3517 - val_categorical_accuracy: 0.6593
# Epoch 19/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.6213 - categorical_accuracy: 0.8146 - val_loss: 1.4158 - val_categorical_accuracy: 0.6552
# Epoch 20/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5854 - categorical_accuracy: 0.8249 - val_loss: 1.2837 - val_categorical_accuracy: 0.6636
# Epoch 21/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5660 - categorical_accuracy: 0.8318 - val_loss: 1.3021 - val_categorical_accuracy: 0.6641
# Epoch 22/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5663 - categorical_accuracy: 0.8307 - val_loss: 1.3006 - val_categorical_accuracy: 0.6606
# Epoch 23/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5543 - categorical_accuracy: 0.8355 - val_loss: 1.3326 - val_categorical_accuracy: 0.6605
# Epoch 24/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5383 - categorical_accuracy: 0.8412 - val_loss: 1.2879 - val_categorical_accuracy: 0.6631
# Epoch 25/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5341 - categorical_accuracy: 0.8429 - val_loss: 1.3062 - val_categorical_accuracy: 0.6626
# Epoch 26/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5312 - categorical_accuracy: 0.8428 - val_loss: 1.3425 - val_categorical_accuracy: 0.6591
# Epoch 27/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5238 - categorical_accuracy: 0.8465 - val_loss: 1.3403 - val_categorical_accuracy: 0.6598
# Epoch 28/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5173 - categorical_accuracy: 0.8483 - val_loss: 1.3619 - val_categorical_accuracy: 0.6603
# Epoch 29/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 12s 18ms/step - loss: 0.5138 - categorical_accuracy: 0.8494 - val_loss: 1.3682 - val_categorical_accuracy: 0.6584
# Epoch 30/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 0.4990 - categorical_accuracy: 0.8538 - val_loss: 1.3289 - val_categorical_accuracy: 0.6612
# Epoch 31/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 12s 18ms/step - loss: 0.4887 - categorical_accuracy: 0.8585 - val_loss: 1.3246 - val_categorical_accuracy: 0.6621
# Epoch 00031: early stopping

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
testEval = model.evaluate(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), ytest, batch_size = BATCH_SIZE)
# Out:
# 11005/11005 [==============================] - 1s 55us/step

# %%
print('Evaluation scores: \nMetrics: {} \nTest: {}'.format(model.metrics_names, testEval))
# Out:
# Evaluation scores:
# Metrics: ['loss', 'categorical_accuracy']
# Test: [1.5360437197015806, 0.6265333939335228]

# %%
ROOT_DIR = os.path.normpath(os.path.join(os.path.dirname(os.path.realpath('__file__'))))
DATA_INFO = os.path.join(ROOT_DIR, 'data_asr', 'data_info')

# %%
test_files = pd.read_csv(os.path.join(DATA_INFO, 'testing_list.txt'), sep = ' ', header = None)[0].tolist()

# %%
test_lab = [os.path.dirname(i) for i in test_files]

# %%
lab = LabelEncoder()

test_encode = lab.fit_transform(test_lab)

# %%
y_pred = model.predict(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), verbose=1)
# Out:
# 11005/11005 [==============================] - 1s 81us/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.figure(figsize=(25,25))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.3f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), size=11,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)
    plt.savefig('cnn1_1k.png', dpi = 400)
    plt.tight_layout()

# %%
classes = ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 
          'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 
          'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree',
          'two', 'up', 'visual', 'wow', 'yes', 'zero']

# %%
cm = confusion_matrix(test_encode, np.argmax(y_pred, 1))

# %%
plot_confusion_matrix(cm, classes, normalize=True)
# Out:
# Normalized confusion matrix

# %%
print(classification_report(test_encode, np.argmax(y_pred, 1), target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#     backward       0.46      0.48      0.47       165
#          bed       0.47      0.51      0.49       207
#         bird       0.63      0.69      0.66       185
#          cat       0.51      0.61      0.56       194
#          dog       0.53      0.47      0.50       220
#         down       0.59      0.57      0.58       406
#        eight       0.67      0.70      0.68       408
#         five       0.66      0.60      0.63       445
#       follow       0.61      0.47      0.53       172
#      forward       0.53      0.42      0.47       155
#         four       0.66      0.65      0.65       400
#           go       0.55      0.48      0.51       402
#        happy       0.69      0.71      0.70       203
#        house       0.71      0.73      0.72       191
#        learn       0.42      0.40      0.41       161
#         left       0.62      0.70      0.66       412
#       marvin       0.69      0.59      0.64       195
#         nine       0.64      0.62      0.63       408
#           no       0.52      0.48      0.50       405
#          off       0.67      0.60      0.64       402
#           on       0.66      0.63      0.64       396
#          one       0.64      0.71      0.67       399
#        right       0.66      0.68      0.67       396
#        seven       0.59      0.74      0.66       406
#       sheila       0.76      0.81      0.78       212
#          six       0.65      0.70      0.67       394
#         stop       0.60      0.63      0.61       411
#        three       0.62      0.60      0.61       405
#         tree       0.59      0.58      0.58       193
#          two       0.60      0.64      0.62       424
#           up       0.46      0.48      0.47       425
#       visual       0.51      0.68      0.58       165
#          wow       0.65      0.56      0.60       206
#          yes       0.76      0.73      0.74       419
#         zero       0.78      0.67      0.72       418
#
#    micro avg       0.62      0.62      0.62     11005
#    macro avg       0.61      0.61      0.61     11005
# weighted avg       0.62      0.62      0.62     11005
