# %%
import os
import numpy as np
import keras
import math
import itertools
import pandas as pd
import matplotlib.pyplot as plt
from kapre.utils import Normalization2D
from keras.models import Sequential
from keras.layers import *
from keras import backend as k
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from keras.preprocessing import sequence
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
train_feat = np.load('train_feat.npy')
val_feat = np.load('val_feat.npy')
test_feat = np.load('test_feat.npy')

ytrain = np.load('ytrain.npy')
yval = np.load('yval.npy')
ytest = np.load('ytest.npy')

# %%
features_dim = 98
wide = 40
N1 = 128
N2 = 1
Nfc1 = 60
Nfc2 = 240
Nfc3 = 120
out_dim = 35
BATCH_SIZE = 128

# %%
model = Sequential()

model.add(Normalization2D(int_axis = 1, input_shape=(features_dim, wide, 1)))

model.add(Permute((2, 1, 3)))

model.add(Conv2D(N1, kernel_size = (1, 4), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))
    
model.add(Conv2D(N2, kernel_size = (1, 2), strides = (1, 2), activation = 'relu'))

model.add(BatchNormalization(axis = -1, scale = None))
    
model.add(MaxPooling2D(pool_size = 2, strides = 1))

model.add(Flatten())

model.add(Dense(Nfc1, activation = 'relu'))

model.add(Dropout(0.3))

model.add(Dense(Nfc2, activation = 'relu'))

model.add(Dropout(0.3))

model.add(Dense(Nfc3, activation = 'relu'))

model.add(Dropout(0.3))

model.add(Dense(out_dim, activation = 'softmax'))

adam_ = optimizers.Adam(lr = 1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = adam_, metrics = ['categorical_accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization2d_1 (Normaliza (None, 98, 40, 1)         0
# _________________________________________________________________
# permute_1 (Permute)          (None, 40, 98, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, 48, 128)       640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 48, 128)       384
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 39, 47, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 39, 23, 1)         257
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 39, 23, 1)         3
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 38, 22, 1)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 836)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                50220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 240)               14640
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 240)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               28920
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 35)                4235
# =================================================================
# Total params: 99,299
# Trainable params: 99,041
# Non-trainable params: 258
# _________________________________________________________________

# %%
batches = int(len(train_feat)/BATCH_SIZE)

# %%
def batch_generator():
    
    while True:

        for batch in range(batches):
            
            x_ = []
            data = train_feat[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            label = ytrain[batch * BATCH_SIZE: (batch + 1) * BATCH_SIZE]
            
            for i in data:
                x_.append(np.reshape(i, (features_dim, wide, 1)))
                 
            x = np.asarray(x_)
            yield (x, label)

# %%
x_val = []

for i in range(len(val_feat)):
    x_val.append(np.reshape(val_feat[i], (features_dim, wide, 1)))
    
valx = np.asarray(x_val)

# %%
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate

# %%
lrate = LearningRateScheduler(step_decay)

# %%
checkpointer = ModelCheckpoint(filepath='checkpoint_asr.h5', monitor='val_categorical_accuracy', save_best_only=True)

# %%
earlystopper = EarlyStopping(monitor='val_categorical_accuracy', patience=10, verbose=1)

# %%
history = model.fit_generator(batch_generator(), steps_per_epoch = batches, epochs = 500, validation_data=(valx, yval), 
                              callbacks=[checkpointer, earlystopper, lrate], shuffle = True)
# Out:
# WARNING:tensorflow:From /home/aumkar/anaconda3/envs/asr/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 21s 32ms/step - loss: 2.8681 - categorical_accuracy: 0.1922 - val_loss: 2.2744 - val_categorical_accuracy: 0.3893
# Epoch 2/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 2.2919 - categorical_accuracy: 0.3349 - val_loss: 1.8650 - val_categorical_accuracy: 0.4900
# Epoch 3/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 2.1043 - categorical_accuracy: 0.3883 - val_loss: 1.6407 - val_categorical_accuracy: 0.5432
# Epoch 4/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 2.0008 - categorical_accuracy: 0.4166 - val_loss: 1.5068 - val_categorical_accuracy: 0.5714
# Epoch 5/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 1.9226 - categorical_accuracy: 0.4387 - val_loss: 1.4546 - val_categorical_accuracy: 0.5847
# Epoch 6/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 1.8828 - categorical_accuracy: 0.4498 - val_loss: 1.4171 - val_categorical_accuracy: 0.5909
# Epoch 7/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 1.8389 - categorical_accuracy: 0.4638 - val_loss: 1.4069 - val_categorical_accuracy: 0.5982
# Epoch 8/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 1.8147 - categorical_accuracy: 0.4704 - val_loss: 1.3776 - val_categorical_accuracy: 0.6074
# Epoch 9/500
# Changing learning rate to 0.001
# 662/662 [==============================] - 20s 30ms/step - loss: 1.7875 - categorical_accuracy: 0.4800 - val_loss: 1.3601 - val_categorical_accuracy: 0.6184
# Epoch 10/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.7301 - categorical_accuracy: 0.4931 - val_loss: 1.3018 - val_categorical_accuracy: 0.6321
# Epoch 11/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.7083 - categorical_accuracy: 0.4983 - val_loss: 1.2853 - val_categorical_accuracy: 0.6340
# Epoch 12/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6979 - categorical_accuracy: 0.5019 - val_loss: 1.3073 - val_categorical_accuracy: 0.6305
# Epoch 13/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6847 - categorical_accuracy: 0.5037 - val_loss: 1.2781 - val_categorical_accuracy: 0.6376
# Epoch 14/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6765 - categorical_accuracy: 0.5068 - val_loss: 1.2786 - val_categorical_accuracy: 0.6360
# Epoch 15/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6715 - categorical_accuracy: 0.5098 - val_loss: 1.3205 - val_categorical_accuracy: 0.6391
# Epoch 16/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6599 - categorical_accuracy: 0.5094 - val_loss: 1.2818 - val_categorical_accuracy: 0.6394
# Epoch 17/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6582 - categorical_accuracy: 0.5115 - val_loss: 1.2722 - val_categorical_accuracy: 0.6408
# Epoch 18/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6512 - categorical_accuracy: 0.5136 - val_loss: 1.2797 - val_categorical_accuracy: 0.6423
# Epoch 19/500
# Changing learning rate to 0.0004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6478 - categorical_accuracy: 0.5154 - val_loss: 1.2610 - val_categorical_accuracy: 0.6453
# Epoch 20/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6265 - categorical_accuracy: 0.5219 - val_loss: 1.2527 - val_categorical_accuracy: 0.6466
# Epoch 21/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6127 - categorical_accuracy: 0.5261 - val_loss: 1.2560 - val_categorical_accuracy: 0.6465
# Epoch 22/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6104 - categorical_accuracy: 0.5253 - val_loss: 1.2515 - val_categorical_accuracy: 0.6457
# Epoch 23/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6040 - categorical_accuracy: 0.5288 - val_loss: 1.2420 - val_categorical_accuracy: 0.6474
# Epoch 24/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6024 - categorical_accuracy: 0.5284 - val_loss: 1.2525 - val_categorical_accuracy: 0.6465
# Epoch 25/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5954 - categorical_accuracy: 0.5281 - val_loss: 1.2327 - val_categorical_accuracy: 0.6519
# Epoch 26/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6015 - categorical_accuracy: 0.5266 - val_loss: 1.2410 - val_categorical_accuracy: 0.6507
# Epoch 27/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6005 - categorical_accuracy: 0.5262 - val_loss: 1.2416 - val_categorical_accuracy: 0.6548
# Epoch 28/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.6028 - categorical_accuracy: 0.5264 - val_loss: 1.2453 - val_categorical_accuracy: 0.6512
# Epoch 29/500
# Changing learning rate to 0.00016000000000000004
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5914 - categorical_accuracy: 0.5310 - val_loss: 1.2628 - val_categorical_accuracy: 0.6500
# Epoch 30/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5839 - categorical_accuracy: 0.5304 - val_loss: 1.2366 - val_categorical_accuracy: 0.6524
# Epoch 31/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5784 - categorical_accuracy: 0.5333 - val_loss: 1.2405 - val_categorical_accuracy: 0.6545
# Epoch 32/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5773 - categorical_accuracy: 0.5331 - val_loss: 1.2352 - val_categorical_accuracy: 0.6526
# Epoch 33/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5756 - categorical_accuracy: 0.5349 - val_loss: 1.2338 - val_categorical_accuracy: 0.6535
# Epoch 34/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5796 - categorical_accuracy: 0.5315 - val_loss: 1.2304 - val_categorical_accuracy: 0.6523
# Epoch 35/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5768 - categorical_accuracy: 0.5338 - val_loss: 1.2297 - val_categorical_accuracy: 0.6523
# Epoch 36/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5762 - categorical_accuracy: 0.5345 - val_loss: 1.2260 - val_categorical_accuracy: 0.6548
# Epoch 37/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5729 - categorical_accuracy: 0.5351 - val_loss: 1.2515 - val_categorical_accuracy: 0.6498
# Epoch 38/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5713 - categorical_accuracy: 0.5354 - val_loss: 1.2278 - val_categorical_accuracy: 0.6528
# Epoch 39/500
# Changing learning rate to 6.400000000000001e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5716 - categorical_accuracy: 0.5344 - val_loss: 1.2267 - val_categorical_accuracy: 0.6539
# Epoch 40/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5682 - categorical_accuracy: 0.5360 - val_loss: 1.2286 - val_categorical_accuracy: 0.6531
# Epoch 41/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5601 - categorical_accuracy: 0.5363 - val_loss: 1.2254 - val_categorical_accuracy: 0.6534
# Epoch 42/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5658 - categorical_accuracy: 0.5363 - val_loss: 1.2277 - val_categorical_accuracy: 0.6541
# Epoch 43/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5663 - categorical_accuracy: 0.5367 - val_loss: 1.2272 - val_categorical_accuracy: 0.6538
# Epoch 44/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5607 - categorical_accuracy: 0.5377 - val_loss: 1.2165 - val_categorical_accuracy: 0.6554
# Epoch 45/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5657 - categorical_accuracy: 0.5359 - val_loss: 1.2233 - val_categorical_accuracy: 0.6545
# Epoch 46/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5634 - categorical_accuracy: 0.5360 - val_loss: 1.2273 - val_categorical_accuracy: 0.6545
# Epoch 47/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5618 - categorical_accuracy: 0.5376 - val_loss: 1.2238 - val_categorical_accuracy: 0.6529
# Epoch 48/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5575 - categorical_accuracy: 0.5398 - val_loss: 1.2270 - val_categorical_accuracy: 0.6561
# Epoch 49/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5526 - categorical_accuracy: 0.5416 - val_loss: 1.2164 - val_categorical_accuracy: 0.6566
# Epoch 50/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5618 - categorical_accuracy: 0.5395 - val_loss: 1.2247 - val_categorical_accuracy: 0.6540
# Epoch 51/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5603 - categorical_accuracy: 0.5388 - val_loss: 1.2196 - val_categorical_accuracy: 0.6565
# Epoch 52/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5619 - categorical_accuracy: 0.5390 - val_loss: 1.2252 - val_categorical_accuracy: 0.6537
# Epoch 53/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5619 - categorical_accuracy: 0.5376 - val_loss: 1.2181 - val_categorical_accuracy: 0.6555
# Epoch 54/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5666 - categorical_accuracy: 0.5371 - val_loss: 1.2250 - val_categorical_accuracy: 0.6558
# Epoch 55/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5593 - categorical_accuracy: 0.5398 - val_loss: 1.2246 - val_categorical_accuracy: 0.6553
# Epoch 56/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5543 - categorical_accuracy: 0.5395 - val_loss: 1.2245 - val_categorical_accuracy: 0.6554
# Epoch 57/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5542 - categorical_accuracy: 0.5386 - val_loss: 1.2235 - val_categorical_accuracy: 0.6557
# Epoch 58/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5581 - categorical_accuracy: 0.5412 - val_loss: 1.2211 - val_categorical_accuracy: 0.6554
# Epoch 59/500
# Changing learning rate to 4e-05
# 662/662 [==============================] - 20s 30ms/step - loss: 1.5525 - categorical_accuracy: 0.5406 - val_loss: 1.2237 - val_categorical_accuracy: 0.6540
# Epoch 00059: early stopping

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
testEval = model.evaluate(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), ytest, batch_size = BATCH_SIZE)
# Out:
# 11005/11005 [==============================] - 1s 82us/step

# %%
print('Evaluation scores: \nMetrics: {} \nTest: {}'.format(model.metrics_names, testEval))
# Out:
# Evaluation scores:
# Metrics: ['loss', 'categorical_accuracy']
# Test: [1.323723123334636, 0.6206269880632334]

# %%
ROOT_DIR = os.path.normpath(os.path.join(os.path.dirname(os.path.realpath('__file__'))))
DATA_INFO = os.path.join(ROOT_DIR, 'data_asr', 'data_info')

# %%
test_files = pd.read_csv(os.path.join(DATA_INFO, 'testing_list.txt'), sep = ' ', header = None)[0].tolist()

# %%
test_lab = [os.path.dirname(i) for i in test_files]

# %%
lab = LabelEncoder()

test_encode = lab.fit_transform(test_lab)

# %%
y_pred = model.predict(np.reshape(test_feat, (len(test_feat), features_dim, wide, 1)), verbose=1)
# Out:
# 11005/11005 [==============================] - 1s 114us/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.figure(figsize=(25,25))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.3f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), size=11,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=30)
    plt.xlabel('Predicted label', fontsize=30)
    plt.tight_layout()

# %%
classes = ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 
          'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 
          'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree',
          'two', 'up', 'visual', 'wow', 'yes', 'zero']

# %%
cm = confusion_matrix(test_encode, np.argmax(y_pred, 1))

# %%
plot_confusion_matrix(cm, classes, normalize=True)
# Out:
# Normalized confusion matrix

# %%
print(classification_report(test_encode, np.argmax(y_pred, 1), target_names = classes))
# Out:
#               precision    recall  f1-score   support
#
#     backward       0.75      0.45      0.56       165
#          bed       0.47      0.59      0.52       207
#         bird       0.63      0.67      0.65       185
#          cat       0.48      0.56      0.51       194
#          dog       0.60      0.27      0.37       220
#         down       0.54      0.57      0.55       406
#        eight       0.68      0.77      0.72       408
#         five       0.70      0.56      0.62       445
#       follow       0.65      0.41      0.50       172
#      forward       0.50      0.12      0.20       155
#         four       0.60      0.68      0.64       400
#           go       0.51      0.52      0.51       402
#        happy       0.77      0.71      0.74       203
#        house       0.77      0.77      0.77       191
#        learn       0.54      0.23      0.32       161
#         left       0.66      0.58      0.62       412
#       marvin       0.62      0.54      0.58       195
#         nine       0.58      0.69      0.63       408
#           no       0.45      0.55      0.49       405
#          off       0.76      0.60      0.67       402
#           on       0.64      0.59      0.61       396
#          one       0.58      0.67      0.62       399
#        right       0.70      0.61      0.65       396
#        seven       0.67      0.80      0.73       406
#       sheila       0.80      0.75      0.77       212
#          six       0.73      0.80      0.76       394
#         stop       0.70      0.76      0.73       411
#        three       0.64      0.68      0.66       405
#         tree       0.58      0.20      0.29       193
#          two       0.51      0.75      0.61       424
#           up       0.40      0.60      0.48       425
#       visual       0.65      0.61      0.63       165
#          wow       0.68      0.55      0.61       206
#          yes       0.75      0.76      0.76       419
#         zero       0.77      0.66      0.71       418
#
#    micro avg       0.62      0.62      0.62     11005
#    macro avg       0.63      0.59      0.59     11005
# weighted avg       0.63      0.62      0.61     11005
